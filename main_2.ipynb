# %% [markdown]
# Step 1: Import Libraries and Set Constants

# %%
import math
import random
import sys
import os
import pygame
import neat
import matplotlib.pyplot as plt

# Constants
WIDTH = 1920
HEIGHT = 1080
CAR_SIZE_X = 60
CAR_SIZE_Y = 60
BORDER_COLOR = (255, 255, 255, 255)
current_generation = 0
Q = {}  # Q-table for storing Q-values
fitness_values = []

# %% [markdown]
# Step 2: Define the Car Class

# %%
class Car:
    def __init__(self):
        self.sprite = pygame.image.load('car.png').convert()
        self.sprite = pygame.transform.scale(self.sprite, (CAR_SIZE_X, CAR_SIZE_Y))
        self.rotated_sprite = self.sprite
        self.position = [830, 920]
        self.angle = 0
        self.speed = 0
        self.speed_set = False
        self.center = [self.position[0] + CAR_SIZE_X / 2, self.position[1] + CAR_SIZE_Y / 2]
        self.radars = []
        self.drawing_radars = []
        self.alive = True
        self.distance = 0
        self.time = 0

    def draw(self, screen):
        screen.blit(self.rotated_sprite, self.position)
        self.draw_radar(screen)

    def draw_radar(self, screen):
        for radar in self.radars:
            position = radar[0]
            pygame.draw.line(screen, (0, 255, 0), self.center, position, 1)
            pygame.draw.circle(screen, (0, 255, 0), position, 5)

    def check_collision(self, game_map):
        self.alive = True
        for point in self.corners:
            if game_map.get_at((int(point[0]), int(point[1]))) == BORDER_COLOR:
                self.alive = False
                break

    def check_radar(self, degree, game_map):
        length = 0
        x = int(self.center[0] + math.cos(math.radians(360 - (self.angle + degree))) * length)
        y = int(self.center[1] + math.sin(math.radians(360 - (self.angle + degree))) * length)

        while not game_map.get_at((x, y)) == BORDER_COLOR and length < 300:
            length += 1
            x = int(self.center[0] + math.cos(math.radians(360 - (self.angle + degree))) * length)
            y = int(self.center[1] + math.sin(math.radians(360 - (self.angle + degree))) * length)

        dist = int(math.sqrt(math.pow(x - self.center[0], 2) + math.pow(y - self.center[1], 2)))
        self.radars.append([(x, y), dist])

    def update(self, game_map):
        if not self.speed_set:
            self.speed = 20
            self.speed_set = True

        self.rotated_sprite = self.rotate_center(self.sprite, self.angle)
        self.position[0] += math.cos(math.radians(360 - self.angle)) * self.speed
        self.position[0] = max(self.position[0], 20)
        self.position[0] = min(self.position[0], WIDTH - 120)

        self.distance += self.speed
        self.time += 1

        self.position[1] += math.sin(math.radians(360 - self.angle)) * self.speed
        self.position[1] = max(self.position[1], 20)
        self.position[1] = min(self.position[1], HEIGHT - 120)

        self.center = [int(self.position[0]) + CAR_SIZE_X / 2, int(self.position[1]) + CAR_SIZE_Y / 2]

        length = 0.5 * CAR_SIZE_X
        left_top = [self.center[0] + math.cos(math.radians(360 - (self.angle + 30))) * length, self.center[1] + math.sin(math.radians(360 - (self.angle + 30))) * length]
        right_top = [self.center[0] + math.cos(math.radians(360 - (self.angle + 150))) * length, self.center[1] + math.sin(math.radians(360 - (self.angle + 150))) * length]
        left_bottom = [self.center[0] + math.cos(math.radians(360 - (self.angle + 210))) * length, self.center[1] + math.sin(math.radians(360 - (self.angle + 210))) * length]
        right_bottom = [self.center[0] + math.cos(math.radians(360 - (self.angle + 330))) * length, self.center[1] + math.sin(math.radians(360 - (self.angle + 330))) * length]
        self.corners = [left_top, right_top, left_bottom, right_bottom]

        self.check_collision(game_map)
        self.radars.clear()

        for d in range(-90, 120, 45):
            self.check_radar(d, game_map)

    def get_data(self):
        radars = self.radars
        return_values = [0, 0, 0, 0, 0]
        for i, radar in enumerate(radars):
            return_values[i] = int(radar[1] / 30)
        return return_values

    def is_alive(self):
        return self.alive

    def get_reward(self):
        return self.distance / (CAR_SIZE_X / 2)

    def rotate_center(self, image, angle):
        rectangle = image.get_rect()
        rotated_image = pygame.transform.rotate(image, angle)
        rotated_rectangle = rectangle.copy()
        rotated_rectangle.center = rotated_image.get_rect().center
        rotated_image = rotated_image.subsurface(rotated_rectangle).copy()
        return rotated_image

    def get_state(self):
        return (int(self.position[0] / 10), int(self.position[1] / 10), self.angle, self.speed)

    def get_action(self, state):
        if state not in Q:
            Q[state] = [0, 0, 0, 0]  # Initialize Q-values for this state
        return Q[state].index(max(Q[state]))  # Choose the action with the highest Q-value

    def update_q_values(self, state, action, next_state, reward):
        if state not in Q:
            Q[state] = [0, 0, 0, 0]
        if next_state not in Q:
            Q[next_state] = [0, 0, 0, 0]
        alpha = 0.1  # Learning rate
        gamma = 0.9  # Discount factor
        Q[state][action] = Q[state][action] + alpha * (reward + gamma * max(Q[next_state]) - Q[state][action])

# %% [markdown]
# Step 3: Define the Simulation Function and Initialize the NEAT Algorithm

# %%
def run_simulation(genomes, config):
    global current_generation
    current_generation += 1

    nets = []
    cars = []

    pygame.init()
    screen = pygame.display.set_mode((WIDTH, HEIGHT), pygame.FULLSCREEN)
    clock = pygame.time.Clock()
    generation_font = pygame.font.SysFont("Arial", 30)
    alive_font = pygame.font.SysFont("Arial", 20)
    game_map = pygame.image.load('map2.png').convert()

    for i, g in genomes:
        net = neat.nn.FeedForwardNetwork.create(g, config)
        nets.append(net)
        g.fitness = 0
        cars.append(Car())

    counter = 0

    while True:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                sys.exit(0)

        for i, car in enumerate(cars):
            state = car.get_state()
            action = car.get_action(state)
            output = nets[i].activate(car.get_data())
            choice = output.index(max(output))
            if choice == 0:
                car.angle += 10
            elif choice == 1:
                car.angle -= 10
            elif choice == 2:
                if car.speed - 2 >= 12:
                    car.speed -= 2
            else:
                car.speed += 2
            next_state = car.get_state()
            reward = car.get_reward()
            car.update_q_values(state, action, next_state, reward)

        still_alive = 0
        for i, car in enumerate(cars):
            if car.is_alive():
                still_alive += 1
                car.update(game_map)
                genomes[i][1].fitness += car.get_reward()

        if still_alive == 0:
            fitness_values.append(stats.get_best_genome().fitness)

            plt.figure()
            plt.plot(fitness_values, label='Fitness')
            plt.xlabel('Generation')
            plt.ylabel('Fitness')
            plt.title('Fitness of Best Genome per Generation')
            plt.legend()
            plt.grid(True)
            plt.show()

            break

        counter += 1
        if counter == 30 * 40:
            break

        screen.blit(game_map, (0, 0))
        for car in cars:
            if car.is_alive():
                car.draw(screen)

        text = generation_font.render("Generation: " + str(current_generation), True, (0, 0, 0))
        text_rect = text.get_rect()
        text_rect.center = (900, 450)
        screen.blit(text, text_rect)

        text = alive_font.render("Still Alive: " + str(still_alive), True, (0, 0, 0))
        text_rect = text.get_rect()
        text_rect.center = (900, 490)
        screen.blit(text, text_rect)

        pygame.display.flip()
        clock.tick(60)

    pygame.quit()

if __name__ == "__main__":
    config_path = "./config.txt"
    config = neat.config.Config(neat.DefaultGenome, neat.DefaultReproduction,
                                 neat.DefaultSpeciesSet, neat.DefaultStagnation, config_path)

    population = neat.Population(config)
    population.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    population.add_reporter(stats)

    population.run(run_simulation, 1000)
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: 9675.29556 stdev: 51876.65237
# Best fitness: 289039.33333 - size: (4, 20) - species 1 - id 8
# Average adjusted fitness: 0.033
# Mean genetic distance 1.223, standard deviation 0.347
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    30  289039.3    0.033     0
# Total extinctions: 0
# Generation time: 20.552 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 17914.78444 stdev: 64772.61875
# Best fitness: 289039.33333 - size: (4, 20) - species 1 - id 8
# Average adjusted fitness: 0.062
# Mean genetic distance 1.443, standard deviation 0.277
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    30  289039.3    0.062     1
# Total extinctions: 0
# Generation time: 20.895 sec (20.724 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 37667.35778 stdev: 93124.34169
# Best fitness: 289198.86667 - size: (4, 20) - species 1 - id 62
# Average adjusted fitness: 0.130
# Mean genetic distance 1.294, standard deviation 0.291
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2    30  289198.9    0.130     0
# Total extinctions: 0
# Generation time: 21.651 sec (21.033 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 69214.87778 stdev: 121994.60920
# Best fitness: 293169.86667 - size: (4, 19) - species 1 - id 107
# Average adjusted fitness: 0.236
# Mean genetic distance 1.058, standard deviation 0.213
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3    30  293169.9    0.236     0
# Total extinctions: 0
# Generation time: 22.361 sec (21.365 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 51019.85778 stdev: 107638.18206
# Best fitness: 293169.86667 - size: (4, 19) - species 1 - id 107
# Average adjusted fitness: 0.174
# Mean genetic distance 1.146, standard deviation 0.202
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    30  293169.9    0.174     1
# Total extinctions: 0
# Generation time: 21.126 sec (21.317 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 63663.85111 stdev: 116043.59989
# Best fitness: 313831.53333 - size: (6, 21) - species 1 - id 150
# Average adjusted fitness: 0.203
# Mean genetic distance 1.311, standard deviation 0.218
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5    30  313831.5    0.203     0
# Total extinctions: 0
# Generation time: 21.669 sec (21.376 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 90533.36667 stdev: 132475.51355
# Best fitness: 313831.53333 - size: (6, 21) - species 1 - id 150
# Average adjusted fitness: 0.288
# Mean genetic distance 1.364, standard deviation 0.207
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6    30  313831.5    0.288     1
# Total extinctions: 0
# Generation time: 22.400 sec (21.522 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 90843.56889 stdev: 133102.88403
# Best fitness: 313831.53333 - size: (6, 21) - species 1 - id 150
# Average adjusted fitness: 0.289
# Mean genetic distance 1.322, standard deviation 0.281
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7    30  313831.5    0.289     2
# Total extinctions: 0
# Generation time: 25.236 sec (21.986 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 80712.55556 stdev: 129791.40651
# Best fitness: 313831.53333 - size: (6, 21) - species 1 - id 150
# Average adjusted fitness: 0.257
# Mean genetic distance 1.270, standard deviation 0.313
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8    30  313831.5    0.257     3
# Total extinctions: 0
# Generation time: 21.760 sec (21.961 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 91724.92222 stdev: 139451.79930
# Best fitness: 370340.26667 - size: (5, 20) - species 1 - id 249
# Average adjusted fitness: 0.248
# Mean genetic distance 1.349, standard deviation 0.275
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    30  370340.3    0.248     0
# Total extinctions: 0
# Generation time: 22.093 sec (21.974 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 84715.58222 stdev: 135127.42676
# Best fitness: 370340.26667 - size: (5, 20) - species 1 - id 249
# Average adjusted fitness: 0.229
# Mean genetic distance 1.427, standard deviation 0.261
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    30  370340.3    0.229     1
# Total extinctions: 0
# Generation time: 22.776 sec (22.197 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 66590.30222 stdev: 123465.26439
# Best fitness: 370340.26667 - size: (5, 20) - species 1 - id 249
# Average adjusted fitness: 0.180
# Mean genetic distance 1.232, standard deviation 0.331
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    30  370340.3    0.180     2
# Total extinctions: 0
# Generation time: 21.963 sec (22.304 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 92167.87111 stdev: 151064.20885
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.192
# Mean genetic distance 1.266, standard deviation 0.285
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    30  480400.0    0.192     0
# Total extinctions: 0
# Generation time: 22.325 sec (22.371 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 137529.87111 stdev: 180571.04734
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.286
# Mean genetic distance 1.326, standard deviation 0.231
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    30  480400.0    0.286     1
# Total extinctions: 0
# Generation time: 25.435 sec (22.678 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 118924.30444 stdev: 168818.91153
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.248
# Mean genetic distance 1.266, standard deviation 0.306
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14    30  480400.0    0.248     2
# Total extinctions: 0
# Generation time: 25.180 sec (23.084 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 172439.37333 stdev: 210559.51015
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.359
# Mean genetic distance 1.070, standard deviation 0.432
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15    30  480400.0    0.359     3
# Total extinctions: 0
# Generation time: 26.959 sec (23.613 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 130015.90667 stdev: 182199.28296
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.271
# Mean genetic distance 1.336, standard deviation 0.421
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16    30  480400.0    0.271     4
# Total extinctions: 0
# Generation time: 23.780 sec (23.751 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 162363.42222 stdev: 204731.18949
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.338
# Mean genetic distance 1.489, standard deviation 0.513
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17    24  480400.0    0.338     5
#      2    0     6       --       --     0
# Total extinctions: 0
# Generation time: 25.019 sec (23.729 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 198909.77111 stdev: 209453.24506
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.423
# Mean genetic distance 1.598, standard deviation 0.526
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18    19  480400.0    0.408     6
#      2    1    11  480400.0    0.438     0
# Total extinctions: 0
# Generation time: 30.072 sec (24.560 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 187139.20667 stdev: 218629.47674
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.410
# Mean genetic distance 1.453, standard deviation 0.525
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19    16  480400.0    0.333     7
#      2    2    14  480400.0    0.488     1
# Total extinctions: 0
# Generation time: 25.359 sec (24.887 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 230404.96444 stdev: 219324.55107
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.480
# Mean genetic distance 1.442, standard deviation 0.568
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20    15  480400.0    0.469     8
#      2    3    15  480400.0    0.492     2
# Total extinctions: 0
# Generation time: 24.890 sec (25.098 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: 244160.39111 stdev: 226377.38884
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.508
# Mean genetic distance 1.422, standard deviation 0.565
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21    16  480400.0    0.513     9
#      2    4    14  480400.0    0.503     3
# Total extinctions: 0
# Generation time: 24.816 sec (25.384 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: 244730.41333 stdev: 220158.07288
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.510
# Mean genetic distance 1.485, standard deviation 0.548
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22    15  480400.0    0.496    10
#      2    5    15  480400.0    0.525     4
# Total extinctions: 0
# Generation time: 26.080 sec (25.759 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 237605.26667 stdev: 212923.43435
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.495
# Mean genetic distance 1.374, standard deviation 0.586
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23    14  480400.0    0.458    11
#      2    6    16  480400.0    0.531     5
# Total extinctions: 0
# Generation time: 25.133 sec (25.729 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: 163346.24444 stdev: 203260.77000
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.338
# Mean genetic distance 1.401, standard deviation 0.558
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24    13  480400.0    0.309    12
#      2    7    17  480400.0    0.367     6
# Total extinctions: 0
# Generation time: 22.170 sec (25.428 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 213469.55778 stdev: 221751.48381
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.435
# Mean genetic distance 1.380, standard deviation 0.571
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25    12  480400.0    0.363    13
#      2    8    18  480400.0    0.507     7
# Total extinctions: 0
# Generation time: 23.572 sec (25.089 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: 251500.64000 stdev: 204604.49535
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.511
# Mean genetic distance 1.406, standard deviation 0.528
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26    13  480400.0    0.448    14
#      2    9    17  480400.0    0.574     8
# Total extinctions: 0
# Generation time: 27.693 sec (25.481 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 214906.43111 stdev: 232504.64633
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.459
# Mean genetic distance 1.418, standard deviation 0.588
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27    15  480400.0    0.551    15
#      2   10    15  480400.0    0.368     9
# Total extinctions: 0
# Generation time: 24.023 sec (25.381 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 223952.90222 stdev: 220795.19542
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.466
# Mean genetic distance 1.429, standard deviation 0.569
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28    16  480400.0    0.482    16
#      2   11    14  480400.0    0.450    10
# Total extinctions: 0
# Generation time: 26.159 sec (24.990 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 167068.50222 stdev: 221913.36869
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.345
# Mean genetic distance 1.462, standard deviation 0.476
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29    17  480400.0    0.389    17
#      2   12    13  480400.0    0.301    11
# Total extinctions: 0
# Generation time: 23.645 sec (24.818 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: 166231.74222 stdev: 212045.43388
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.346
# Mean genetic distance 1.570, standard deviation 0.517
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30    12  480400.0    0.344    18
#      2   13    14  480400.0    0.348    12
#      3    0     4       --       --     0
# Total extinctions: 0
# Generation time: 22.066 sec (24.536 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 251873.40667 stdev: 209033.38359
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.468
# Mean genetic distance 1.614, standard deviation 0.510
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31    13  480400.0    0.651    19
#      2   14    12  480400.0    0.490    13
#      3    1     5  242252.0    0.263     0
# Total extinctions: 0
# Generation time: 28.452 sec (24.900 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 187600.19778 stdev: 214102.26826
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.396
# Mean genetic distance 1.532, standard deviation 0.485
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32     6  480400.0    0.374    20
#      2   15    11  480400.0    0.398    14
#      3    2    13  480400.0    0.415     0
# Total extinctions: 0
# Generation time: 23.783 sec (24.670 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 210928.37333 stdev: 225751.74758
# Best fitness: 480400.00000 - size: (9, 21) - species 3 - id 835
# Average adjusted fitness: 0.454
# Mean genetic distance 1.434, standard deviation 0.530
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33     9  480400.0    0.508    21
#      2   16    10  480400.0    0.483    15
#      3    3    11  480400.0    0.370     1
# Total extinctions: 0
# Generation time: 24.143 sec (24.571 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: 286794.08000 stdev: 221730.99030
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.606
# Mean genetic distance 1.364, standard deviation 0.516
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34    10  480400.0    0.713    22
#      2   17    11  480400.0    0.663    16
#      3    4     9  480400.0    0.442     2
# Total extinctions: 0
# Generation time: 27.811 sec (25.135 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 264239.07556 stdev: 226609.77482
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.555
# Mean genetic distance 1.376, standard deviation 0.505
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35    11  480400.0    0.705    23
#      2   18     9  480400.0    0.401    17
#      3    5    10  480400.0    0.561     3
# Total extinctions: 0
# Generation time: 29.721 sec (25.750 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: 290532.88000 stdev: 232562.65348
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.616
# Mean genetic distance 1.399, standard deviation 0.511
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   36     8  480400.0    0.552    24
#      2   19    12  480400.0    0.889    18
#      3    6    10  480400.0    0.407     4
# Total extinctions: 0
# Generation time: 27.289 sec (25.709 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: 291767.20667 stdev: 231205.47317
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.603
# Mean genetic distance 1.385, standard deviation 0.502
# Population of 31 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   37     8  480400.0    0.520    25
#      2   20    11  480400.0    0.586    19
#      3    7    12  480400.0    0.703     5
# Total extinctions: 0
# Generation time: 27.108 sec (26.018 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: 246124.24086 stdev: 223250.25549
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.525
# Mean genetic distance 1.388, standard deviation 0.534
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   38     9  480400.0    0.627    26
#      2   21    10  480400.0    0.524    20
#      3    8    11  480400.0    0.426     6
# Total extinctions: 0
# Generation time: 25.908 sec (25.993 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: 240511.05778 stdev: 228995.01218
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.498
# Mean genetic distance 1.404, standard deviation 0.547
# Population of 31 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   39     9  480400.0    0.451    27
#      2   22    11  480400.0    0.516    21
#      3    9    11  480400.0    0.527     7
# Total extinctions: 0
# Generation time: 25.065 sec (26.135 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: 295585.24301 stdev: 214306.08826
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.615
# Mean genetic distance 1.376, standard deviation 0.520
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   40    10  480400.0    0.614    28
#      2   23    10  480400.0    0.629    22
#      3   10    10  480400.0    0.602     8
# Total extinctions: 0
# Generation time: 30.745 sec (27.002 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: 250054.13333 stdev: 230425.37344
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.520
# Mean genetic distance 1.374, standard deviation 0.504
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   41     9  480400.0    0.407    29
#      2   24    12  480400.0    0.685    23
#      3   11     9  480400.0    0.470     9
# Total extinctions: 0
# Generation time: 25.859 sec (26.743 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: 260375.37111 stdev: 225239.94138
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.544
# Mean genetic distance 1.386, standard deviation 0.505
# Population of 29 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   42    10  480400.0    0.649    30
#      2   25    11  480400.0    0.521    24
#      3   12     8  480400.0    0.464    10
# Total extinctions: 0
# Generation time: 26.962 sec (27.061 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: 240853.31264 stdev: 226802.93830
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.495
# Mean genetic distance 1.366, standard deviation 0.505
# Population of 31 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   43    11  480400.0    0.605    31
#      2   26    11  480400.0    0.485    25
#      3   13     9  480400.0    0.393    11
# Total extinctions: 0
# Generation time: 26.632 sec (27.310 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: 271552.91613 stdev: 206366.03720
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.570
# Mean genetic distance 1.374, standard deviation 0.517
# Population of 31 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   44    12  480400.0    0.684    32
#      2   27     9  480400.0    0.377    26
#      3   14    10  480400.0    0.651    12
# Total extinctions: 0
# Generation time: 38.678 sec (28.397 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: 260531.49247 stdev: 232350.35112
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.538
# Mean genetic distance 1.382, standard deviation 0.548
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   45    11  480400.0    0.588    33
#      2   28    10  480400.0    0.519    27
#      3   15     9  480400.0    0.508    13
# Total extinctions: 0
# Generation time: 31.711 sec (28.596 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: 290828.46444 stdev: 223947.35170
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.596
# Mean genetic distance 1.397, standard deviation 0.560
# Population of 31 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   46    12  480400.0    0.687    34
#      2   29    11  480400.0    0.702    28
#      3   16     8  480400.0    0.398    14
# Total extinctions: 0
# Generation time: 29.497 sec (28.817 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: 207664.36774 stdev: 227395.71561
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.430
# Mean genetic distance 1.415, standard deviation 0.534
# Population of 31 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   47    10  480400.0    0.364    35
#      2   30    12  480400.0    0.541    29
#      3   17     9  480400.0    0.385    15
# Total extinctions: 0
# Generation time: 25.430 sec (28.649 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: 295768.98925 stdev: 221745.24405
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.626
# Mean genetic distance 1.386, standard deviation 0.539
# Population of 29 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   48    12  480400.0    0.901    36
#      2   31     9  480400.0    0.429    30
#      3   18     8  480400.0    0.548    16
# Total extinctions: 0
# Generation time: 29.408 sec (28.999 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: 228889.59310 stdev: 232357.91041
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.497
# Mean genetic distance 1.425, standard deviation 0.529
# Population of 29 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   49     8  480400.0    0.344    37
#      2   32    10  480400.0    0.519    31
#      3   19    11  480400.0    0.628    17
# Total extinctions: 0
# Generation time: 24.221 sec (28.914 average)
#
#  ****** Running generation 50 ******
#
# Population's average fitness: 254206.33103 stdev: 227708.45346
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.537
# Mean genetic distance 1.387, standard deviation 0.529
# Population of 29 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   50    10  480400.0    0.653    38
#      2   33     9  480400.0    0.406    32
#      3   20    10  480400.0    0.551    18
# Total extinctions: 0
# Generation time: 26.693 sec (28.509 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: 219264.14943 stdev: 226970.70882
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
# Average adjusted fitness: 0.458
# Mean genetic distance 1.385, standard deviation 0.556
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   51    11  480400.0    0.508    39
#      2   34    10  480400.0    0.494    33
#      3   21     9  480400.0    0.372    19
# Total extinctions: 0
# Generation time: 24.572 sec (28.380 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: 220248.64222 stdev: 233271.82668
# Best fitness: 480400.00000 - size: (8, 20) - species 3 - id 517
#
# Species 3 with 9 members is stagnated: removing it
# Average adjusted fitness: 0.429
# Mean genetic distance 1.346, standard deviation 0.573
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   52    17  480400.0    0.550    40
#      2   35    13  480400.0    0.309    34
# Total extinctions: 0
# Generation time: 24.308 sec (28.115 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: 263777.29778 stdev: 224968.63990
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.558
# Mean genetic distance 1.339, standard deviation 0.571
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   53    15  480400.0    0.494    41
#      2   36    15  480400.0    0.621    35
# Total extinctions: 0
# Generation time: 27.688 sec (28.221 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: 211837.34444 stdev: 214703.51494
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.441
# Mean genetic distance 1.328, standard deviation 0.586
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   54    16  480400.0    0.447    42
#      2   37    14  480400.0    0.435    36
# Total extinctions: 0
# Generation time: 25.826 sec (26.935 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: 206002.52222 stdev: 223225.47289
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.425
# Mean genetic distance 1.354, standard deviation 0.560
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   55    17  480400.0    0.481    43
#      2   38    13  480400.0    0.369    37
# Total extinctions: 0
# Generation time: 24.047 sec (26.169 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: 211949.02000 stdev: 224786.46278
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.440
# Mean genetic distance 1.362, standard deviation 0.538
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   56    16  480400.0    0.451    44
#      2   39    14  480400.0    0.429    38
# Total extinctions: 0
# Generation time: 24.189 sec (25.638 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: 193446.36444 stdev: 200930.97053
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.401
# Mean genetic distance 1.354, standard deviation 0.535
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   57    15  480400.0    0.421    45
#      2   40    15  480400.0    0.382    39
# Total extinctions: 0
# Generation time: 24.358 sec (25.531 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: 155530.49333 stdev: 213823.03581
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.324
# Mean genetic distance 1.305, standard deviation 0.594
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   58    16  480400.0    0.339    46
#      2   41    14  480400.0    0.309    40
# Total extinctions: 0
# Generation time: 22.758 sec (24.866 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: 166228.76889 stdev: 218142.97755
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.357
# Mean genetic distance 1.321, standard deviation 0.545
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   59    12  480400.0    0.194    47
#      2   42    18  480400.0    0.520    41
# Total extinctions: 0
# Generation time: 22.316 sec (24.676 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: 195984.77556 stdev: 218223.62986
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.409
# Mean genetic distance 1.305, standard deviation 0.574
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   60    14  480400.0    0.413    48
#      2   43    16  480400.0    0.404    42
# Total extinctions: 0
# Generation time: 23.982 sec (24.404 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: 234920.12222 stdev: 212878.12982
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.498
# Mean genetic distance 1.330, standard deviation 0.523
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   61    17  480400.0    0.638    49
#      2   44    13  480400.0    0.359    43
# Total extinctions: 0
# Generation time: 27.110 sec (24.658 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: 223981.04444 stdev: 216734.77825
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.475
# Mean genetic distance 1.324, standard deviation 0.570
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   62    15  480400.0    0.412    50
#      2   45    15  480400.0    0.537    44
# Total extinctions: 0
# Generation time: 26.075 sec (24.835 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: 242073.20667 stdev: 216800.75524
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.504
# Mean genetic distance 1.310, standard deviation 0.598
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   63    16  480400.0    0.507    51
#      2   46    14  480400.0    0.501    45
# Total extinctions: 0
# Generation time: 26.672 sec (24.733 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: 227341.96222 stdev: 222654.74464
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.470
# Mean genetic distance 1.418, standard deviation 0.491
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   64    17  480400.0    0.518    52
#      2   47    13  480400.0    0.422    46
# Total extinctions: 0
# Generation time: 26.234 sec (24.774 average)
#
#  ****** Running generation 65 ******
#
# Population's average fitness: 178317.16667 stdev: 218939.67028
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.366
# Mean genetic distance 1.382, standard deviation 0.527
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   65    16  480400.0    0.408    53
#      2   48    14  480400.0    0.323    47
# Total extinctions: 0
# Generation time: 23.391 sec (24.708 average)
#
#  ****** Running generation 66 ******
#
# Population's average fitness: 162197.96444 stdev: 219329.38767
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.335
# Mean genetic distance 1.409, standard deviation 0.569
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   66    17  480400.0    0.379    54
#      2   49    13  480400.0    0.291    48
# Total extinctions: 0
# Generation time: 22.919 sec (24.581 average)
#
#  ****** Running generation 67 ******
#
# Population's average fitness: 247453.71778 stdev: 212456.48443
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.517
# Mean genetic distance 1.347, standard deviation 0.574
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   67    16  480400.0    0.506    55
#      2   50    14  480400.0    0.527    49
# Total extinctions: 0
# Generation time: 28.044 sec (24.950 average)
#
#  ****** Running generation 68 ******
#
# Population's average fitness: 191500.95333 stdev: 211309.83723
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.401
# Mean genetic distance 1.333, standard deviation 0.530
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   68    15  480400.0    0.368    56
#      2   51    15  480400.0    0.433    50
# Total extinctions: 0
# Generation time: 24.154 sec (25.090 average)
#
#  ****** Running generation 69 ******
#
# Population's average fitness: 168860.91556 stdev: 211067.81864
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.351
# Mean genetic distance 1.357, standard deviation 0.551
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   69    14  480400.0    0.323    57
#      2   52    16  480400.0    0.380    51
# Total extinctions: 0
# Generation time: 23.402 sec (25.198 average)
#
#  ****** Running generation 70 ******
#
# Population's average fitness: 206468.29111 stdev: 219544.98604
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.436
# Mean genetic distance 1.332, standard deviation 0.538
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   70    16  480400.0    0.535    58
#      2   53    14  480400.0    0.337    52
# Total extinctions: 0
# Generation time: 24.897 sec (25.290 average)
#
#  ****** Running generation 71 ******
#
# Population's average fitness: 235156.22889 stdev: 199552.38277
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.489
# Mean genetic distance 1.358, standard deviation 0.548
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   71    15  480400.0    0.499    59
#      2   54    15  480400.0    0.479    53
# Total extinctions: 0
# Generation time: 28.327 sec (25.411 average)
#
#  ****** Running generation 72 ******
#
# Population's average fitness: 177336.13333 stdev: 219388.83041
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.369
# Mean genetic distance 1.341, standard deviation 0.550
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   72    17  480400.0    0.445    60
#      2   55    13  480400.0    0.293    54
# Total extinctions: 0
# Generation time: 23.092 sec (25.113 average)
#
#  ****** Running generation 73 ******
#
# Population's average fitness: 308349.53333 stdev: 206028.80886
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.628
# Mean genetic distance 1.357, standard deviation 0.577
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   73    18  480400.0    0.735    61
#      2   56    12  480400.0    0.520    55
# Total extinctions: 0
# Generation time: 32.737 sec (25.720 average)
#
#  ****** Running generation 74 ******
#
# Population's average fitness: 189717.47556 stdev: 227032.26160
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.408
# Mean genetic distance 1.326, standard deviation 0.547
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   74    15  480400.0    0.344    62
#      2   57    15  480400.0    0.471    56
# Total extinctions: 0
# Generation time: 24.093 sec (25.506 average)
#
#  ****** Running generation 75 ******
#
# Population's average fitness: 171424.85556 stdev: 202191.79089
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.357
# Mean genetic distance 1.325, standard deviation 0.546
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   75    16  480400.0    0.418    63
#      2   58    14  480400.0    0.295    57
# Total extinctions: 0
# Generation time: 23.882 sec (25.555 average)
#
#  ****** Running generation 76 ******
#
# Population's average fitness: 199248.91556 stdev: 218494.40390
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.417
# Mean genetic distance 1.353, standard deviation 0.548
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   76    15  480400.0    0.382    64
#      2   59    15  480400.0    0.452    58
# Total extinctions: 0
# Generation time: 24.202 sec (25.683 average)
#
#  ****** Running generation 77 ******
#
# Population's average fitness: 185636.30889 stdev: 212029.87211
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.386
# Mean genetic distance 1.324, standard deviation 0.599
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   77    14  480400.0    0.340    65
#      2   60    16  480400.0    0.432    59
# Total extinctions: 0
# Generation time: 24.365 sec (25.315 average)
#
#  ****** Running generation 78 ******
#
# Population's average fitness: 205845.19778 stdev: 214217.36611
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.423
# Mean genetic distance 1.299, standard deviation 0.607
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   78    13  480400.0    0.347    66
#      2   61    17  480400.0    0.499    60
# Total extinctions: 0
# Generation time: 25.467 sec (25.446 average)
#
#  ****** Running generation 79 ******
#
# Population's average fitness: 208130.77556 stdev: 221175.06683
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.451
# Mean genetic distance 1.318, standard deviation 0.562
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   79    16  480400.0    0.585    67
#      2   62    14  480400.0    0.317    61
# Total extinctions: 0
# Generation time: 24.408 sec (25.547 average)
#
#  ****** Running generation 80 ******
#
# Population's average fitness: 185323.37333 stdev: 214160.99729
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.379
# Mean genetic distance 1.359, standard deviation 0.574
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   80    18  480400.0    0.486    68
#      2   63    12  480400.0    0.271    62
# Total extinctions: 0
# Generation time: 24.213 sec (25.479 average)
#
#  ****** Running generation 81 ******
#
# Population's average fitness: 237264.20000 stdev: 225289.91974
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.504
# Mean genetic distance 1.316, standard deviation 0.576
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   81    16  480400.0    0.454    69
#      2   64    14  480400.0    0.554    63
# Total extinctions: 0
# Generation time: 26.246 sec (25.270 average)
#
#  ****** Running generation 82 ******
#
# Population's average fitness: 174749.29111 stdev: 208408.83477
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.358
# Mean genetic distance 1.358, standard deviation 0.572
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   82    17  480400.0    0.444    70
#      2   65    13  480400.0    0.272    64
# Total extinctions: 0
# Generation time: 23.163 sec (25.278 average)
#
#  ****** Running generation 83 ******
#
# Population's average fitness: 235618.06667 stdev: 220472.83296
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.484
# Mean genetic distance 1.334, standard deviation 0.588
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   83    16  480400.0    0.529    71
#      2   66    14  480400.0    0.440    65
# Total extinctions: 0
# Generation time: 26.821 sec (24.686 average)
#
#  ****** Running generation 84 ******
#
# Population's average fitness: 235450.81333 stdev: 215433.96824
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.487
# Mean genetic distance 1.411, standard deviation 0.581
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   84    17  480400.0    0.539    72
#      2   67    13  480400.0    0.434    66
# Total extinctions: 0
# Generation time: 26.964 sec (24.973 average)
#
#  ****** Running generation 85 ******
#
# Population's average fitness: 154444.77333 stdev: 208350.30234
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.323
# Mean genetic distance 1.384, standard deviation 0.558
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   85    16  480400.0    0.315    73
#      2   68    14  480400.0    0.330    67
# Total extinctions: 0
# Generation time: 23.226 sec (24.907 average)
#
#  ****** Running generation 86 ******
#
# Population's average fitness: 204965.38889 stdev: 229480.50874
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.423
# Mean genetic distance 1.370, standard deviation 0.570
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   86    17  480400.0    0.484    74
#      2   69    13  480400.0    0.361    68
# Total extinctions: 0
# Generation time: 23.853 sec (24.873 average)
#
#  ****** Running generation 87 ******
#
# Population's average fitness: 216381.74222 stdev: 213269.27129
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.470
# Mean genetic distance 1.320, standard deviation 0.581
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   87    14  480400.0    0.324    75
#      2   70    16  480400.0    0.616    69
# Total extinctions: 0
# Generation time: 25.943 sec (25.030 average)
#
#  ****** Running generation 88 ******
#
# Population's average fitness: 178954.27556 stdev: 224099.21958
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.377
# Mean genetic distance 1.377, standard deviation 0.565
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   88    16  480400.0    0.439    76
#      2   71    14  480400.0    0.315    70
# Total extinctions: 0
# Generation time: 22.580 sec (24.742 average)
#
#  ****** Running generation 89 ******
#
# Population's average fitness: 177623.72889 stdev: 218923.68676
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.364
# Mean genetic distance 1.265, standard deviation 0.592
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   89    17  480400.0    0.449    77
#      2   72    13  480400.0    0.279    71
# Total extinctions: 0
# Generation time: 23.274 sec (24.628 average)
#
#  ****** Running generation 90 ******
#
# Population's average fitness: 231209.14667 stdev: 207674.33707
# Best fitness: 480400.00000 - size: (7, 21) - species 1 - id 332
# Average adjusted fitness: 0.474
# Mean genetic distance 1.348, standard deviation 0.565
# ...
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4  321    18  480400.0    0.480   320
#      5  198    12  480400.0    0.280   197
# Total extinctions: 0
# Generation time: 21.020 sec (21.038 average)
#
#  ****** Running generation 972 ******
#
# Population's average fitness: 166735.53333 stdev: 214136.46360
# Best fitness: 480400.00000 - size: (5, 15) - species 4 - id 15618
# Average adjusted fitness: 0.351
# Mean genetic distance 1.273, standard deviation 0.511
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4  322    16  480400.0    0.332   321
#      5  199    14  480400.0    0.369   198
# Total extinctions: 0
# Generation time: 20.831 sec (21.010 average)
#
#  ****** Running generation 973 ******
#
# Population's average fitness: 213308.15111 stdev: 233748.66482
# Best fitness: 480400.00000 - size: (5, 15) - species 4 - id 15618
# Average adjusted fitness: 0.440
# Mean genetic distance 1.339, standard deviation 0.469
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4  323    17  480400.0    0.506   322
#      5  200    13  480400.0    0.373   199
# Total extinctions: 0
# Generation time: 21.320 sec (20.955 average)
#
#  ****** Running generation 974 ******
#
# Population's average fitness: 214348.04000 stdev: 227853.01151
# Best fitness: 480400.00000 - size: (5, 15) - species 4 - id 15618
# Average adjusted fitness: 0.431
# Mean genetic distance 1.339, standard deviation 0.483
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4  324    18  480400.0    0.545   323
#      5  201    12  480400.0    0.317   200
# Total extinctions: 0
# Generation time: 21.213 sec (20.879 average)
#
#  ****** Running generation 975 ******
#
# Population's average fitness: 152952.48444 stdev: 210775.96602
# Best fitness: 480400.00000 - size: (5, 15) - species 4 - id 15618
# Average adjusted fitness: 0.311
# Mean genetic distance 1.371, standard deviation 0.480
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4  325    17  480400.0    0.348   324
#      5  202    13  480400.0    0.274   201
# Total extinctions: 0
# Generation time: 20.547 sec (20.859 average)
#
#  ****** Running generation 976 ******
#
# Population's average fitness: 215767.13556 stdev: 221715.71251
# Best fitness: 480400.00000 - size: (5, 15) - species 4 - id 15618
# Average adjusted fitness: 0.444
# Mean genetic distance 1.379, standard deviation 0.520
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4  326    16  480400.0    0.481   325
#      5  203    14  480400.0    0.407   202
# Total extinctions: 0
# Generation time: 21.361 sec (20.904 average)
#
#  ****** Running generation 977 ******
#
# Population's average fitness: 212252.42889 stdev: 219665.94482
# Best fitness: 480400.00000 - size: (5, 15) - species 4 - id 15618
# Average adjusted fitness: 0.434
# Mean genetic distance 1.296, standard deviation 0.487
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4  327    18  480400.0    0.554   326
#      5  204    12  480400.0    0.314   203
# Total extinctions: 0
# Generation time: 21.289 sec (20.998 average)
#
#  ****** Running generation 978 ******
#
# Population's average fitness: 228643.19111 stdev: 228202.41084
# Best fitness: 480400.00000 - size: (5, 15) - species 4 - id 15618
# Average adjusted fitness: 0.460
# Mean genetic distance 1.341, standard deviation 0.494
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4  328    17  480400.0    0.541   327
#      5  205    13  480400.0    0.378   204
# Total extinctions: 0
# Generation time: 21.482 sec (21.046 average)
#
#  ****** Running generation 979 ******
#
# Population's average fitness: 240913.21778 stdev: 224858.26805
# Best fitness: 480400.00000 - size: (5, 15) - species 4 - id 15618
# Average adjusted fitness: 0.484
# Mean genetic distance 1.444, standard deviation 0.461
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4  329    18  480400.0    0.613   328
#      5  206    12  480400.0    0.356   205
# Total extinctions: 0
# Generation time: 21.659 sec (21.122 average)
#
#  ****** Running generation 980 ******
#
# Population's average fitness: 193348.24444 stdev: 214686.03483
# Best fitness: 480400.00000 - size: (5, 15) - species 4 - id 15618
# Average adjusted fitness: 0.385
# Mean genetic distance 1.420, standard deviation 0.439
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4  330    19  480400.0    0.474   329
#      5  207    11  480400.0    0.295   206
# Total extinctions: 0
# Generation time: 20.713 sec (21.143 average)
#
#  ****** Running generation 981 ******
#
# Population's average fitness: 195114.12667 stdev: 232966.26341
# Best fitness: 480400.00000 - size: (5, 15) - species 4 - id 15618
# Average adjusted fitness: 0.380
# Mean genetic distance 1.631, standard deviation 0.519
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4  331    13  480400.0    0.478   330
#      5  208    12  480400.0    0.282   207
#      7    0     5       --       --     0
# Total extinctions: 0
# Generation time: 20.616 sec (21.103 average)
#
#  ****** Running generation 982 ******
#
# Population's average fitness: 210051.69556 stdev: 220766.48201
# Best fitness: 480400.00000 - size: (5, 15) - species 4 - id 15618
#
# Species 4 with 13 members is stagnated: removing it
# Average adjusted fitness: 0.400
# Mean genetic distance 1.613, standard deviation 0.504
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  209    17  480400.0    0.385   208
#      7    1    13  480400.0    0.414     0
# Total extinctions: 0
# Generation time: 23.474 sec (21.367 average)
#
#  ****** Running generation 983 ******
#
# Population's average fitness: 168109.43333 stdev: 205078.86037
# Best fitness: 480400.00000 - size: (7, 20) - species 5 - id 18567
# Average adjusted fitness: 0.361
# Mean genetic distance 1.728, standard deviation 0.601
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  210    13  480400.0    0.280   209
#      7    2    16  480400.0    0.441     1
#      8    0     1       --       --     0
# Total extinctions: 0
# Generation time: 22.756 sec (21.511 average)
#
#  ****** Running generation 984 ******
#
# Population's average fitness: 224718.53778 stdev: 221720.70468
# Best fitness: 480400.00000 - size: (7, 20) - species 5 - id 18567
# Average adjusted fitness: 0.559
# Mean genetic distance 1.714, standard deviation 0.693
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  211    10  480400.0    0.373   210
#      7    3    13  480400.0    0.525     2
#      8    1     7  373474.0    0.777     0
# Total extinctions: 0
# Generation time: 25.048 sec (21.894 average)
#
#  ****** Running generation 985 ******
#
# Population's average fitness: 191334.98000 stdev: 229544.29688
# Best fitness: 480400.00000 - size: (7, 17) - species 8 - id 23586
# Average adjusted fitness: 0.400
# Mean genetic distance 1.765, standard deviation 0.741
# Population of 31 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  212    11  480400.0    0.409   211
#      7    4    11  480400.0    0.387     3
#      8    2     9  480400.0    0.404     0
# Total extinctions: 0
# Generation time: 22.825 sec (22.122 average)
#
#  ****** Running generation 986 ******
#
# Population's average fitness: 215797.89677 stdev: 224418.07507
# Best fitness: 480400.00000 - size: (7, 17) - species 8 - id 23586
# Average adjusted fitness: 0.461
# Mean genetic distance 1.753, standard deviation 0.755
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  213     9  480400.0    0.285   212
#      7    5    10  480400.0    0.453     4
#      8    3    11  480400.0    0.645     1
# Total extinctions: 0
# Generation time: 24.384 sec (22.425 average)
#
#  ****** Running generation 987 ******
#
# Population's average fitness: 240072.80667 stdev: 231019.83645
# Best fitness: 480400.00000 - size: (7, 17) - species 8 - id 23586
# Average adjusted fitness: 0.499
# Mean genetic distance 1.793, standard deviation 0.755
# Population of 29 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  214     8  480400.0    0.446   213
#      7    6    11  480400.0    0.567     5
#      8    4    10  480400.0    0.482     2
# Total extinctions: 0
# Generation time: 23.643 sec (22.660 average)
#
#  ****** Running generation 988 ******
#
# Population's average fitness: 241846.36782 stdev: 231120.40893
# Best fitness: 480400.00000 - size: (6, 15) - species 8 - id 23587
# Average adjusted fitness: 0.496
# Mean genetic distance 1.775, standard deviation 0.738
# Population of 31 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  215     8  480400.0    0.384   214
#      7    7    11  480400.0    0.498     6
#      8    5    12  480400.0    0.605     3
# Total extinctions: 0
# Generation time: 23.339 sec (22.846 average)
#
#  ****** Running generation 989 ******
#
# Population's average fitness: 235192.46667 stdev: 229597.41970
# Best fitness: 480400.00000 - size: (6, 15) - species 8 - id 23587
# Average adjusted fitness: 0.475
# Mean genetic distance 1.868, standard deviation 0.739
# Population of 31 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  216     9  480400.0    0.385   215
#      7    8     9  480400.0    0.370     7
#      8    6    13  480400.0    0.669     4
# Total extinctions: 0
# Generation time: 22.121 sec (22.892 average)
#
#  ****** Running generation 990 ******
#
# Population's average fitness: 255573.15269 stdev: 231402.94712
# Best fitness: 480400.00000 - size: (6, 15) - species 8 - id 23587
# Average adjusted fitness: 0.526
# Mean genetic distance 1.804, standard deviation 0.775
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  217     8  480400.0    0.452   216
#      7    9    10  480400.0    0.556     8
#      8    7    12  480400.0    0.571     5
# Total extinctions: 0
# Generation time: 23.590 sec (23.180 average)
#
#  ****** Running generation 991 ******
#
# Population's average fitness: 216314.34222 stdev: 231995.91781
# Best fitness: 480400.00000 - size: (6, 15) - species 8 - id 23587
# Average adjusted fitness: 0.440
# Mean genetic distance 1.863, standard deviation 0.774
# Population of 31 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  218     9  480400.0    0.384   217
#      7   10     9  480400.0    0.407     9
#      8    8    13  480400.0    0.531     6
# Total extinctions: 0
# Generation time: 21.947 sec (23.313 average)
#
#  ****** Running generation 992 ******
#
# Population's average fitness: 230724.97634 stdev: 223777.15893
# Best fitness: 480400.00000 - size: (6, 15) - species 8 - id 23587
# Average adjusted fitness: 0.481
# Mean genetic distance 1.825, standard deviation 0.756
# Population of 29 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  219    10  480400.0    0.561   218
#      7   11     8  480400.0    0.405    10
#      8    9    11  480400.0    0.476     7
# Total extinctions: 0
# Generation time: 23.395 sec (23.305 average)
#
#  ****** Running generation 993 ******
#
# Population's average fitness: 246795.14713 stdev: 233024.01853
# Best fitness: 480400.00000 - size: (6, 15) - species 8 - id 23587
# Average adjusted fitness: 0.503
# Mean genetic distance 1.845, standard deviation 0.770
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  220     8  480400.0    0.306   219
#      7   12     9  480400.0    0.466    11
#      8   10    13  480400.0    0.738     8
# Total extinctions: 0
# Generation time: 22.426 sec (23.272 average)
#
#  ****** Running generation 994 ******
#
# Population's average fitness: 232198.96889 stdev: 226307.64678
# Best fitness: 480400.00000 - size: (6, 15) - species 8 - id 23587
# Average adjusted fitness: 0.489
# Mean genetic distance 1.846, standard deviation 0.767
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  221     9  480400.0    0.504   220
#      7   13    10  480400.0    0.515    12
#      8   11    11  480400.0    0.449     9
# Total extinctions: 0
# Generation time: 22.588 sec (23.026 average)
#
#  ****** Running generation 995 ******
#
# Population's average fitness: 251459.11778 stdev: 234452.05897
# Best fitness: 480400.00000 - size: (6, 15) - species 8 - id 23587
# Average adjusted fitness: 0.516
# Mean genetic distance 1.817, standard deviation 0.758
# Population of 29 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  222     8  480400.0    0.336   221
#      7   14    11  480400.0    0.663    13
#      8   12    10  480400.0    0.550    10
# Total extinctions: 0
# Generation time: 23.210 sec (23.064 average)
#
#  ****** Running generation 996 ******
#
# Population's average fitness: 315812.21149 stdev: 213517.69992
# Best fitness: 480400.00000 - size: (6, 15) - species 8 - id 23587
# Average adjusted fitness: 0.650
# Mean genetic distance 1.882, standard deviation 0.764
# Population of 29 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  223     7  480400.0    0.506   222
#      7   15    10  480400.0    0.590    14
#      8   13    12  480400.0    0.853    11
# Total extinctions: 0
# Generation time: 25.223 sec (23.148 average)
#
#  ****** Running generation 997 ******
#
# Population's average fitness: 234964.83218 stdev: 227862.69281
# Best fitness: 480400.00000 - size: (6, 15) - species 8 - id 23587
# Average adjusted fitness: 0.481
# Mean genetic distance 1.789, standard deviation 0.796
# Population of 31 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  224     9  480400.0    0.438   223
#      7   16    10  480400.0    0.474    15
#      8   14    12  480400.0    0.532    12
# Total extinctions: 0
# Generation time: 22.508 sec (23.035 average)
#
#  ****** Running generation 998 ******
#
# Population's average fitness: 279421.73548 stdev: 225808.18041
# Best fitness: 480400.00000 - size: (6, 15) - species 8 - id 23587
# Average adjusted fitness: 0.558
# Mean genetic distance 1.823, standard deviation 0.803
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  225     8  480400.0    0.342   224
#      7   17     9  480400.0    0.516    16
#      8   15    13  480400.0    0.816    13
# Total extinctions: 0
# Generation time: 24.609 sec (23.162 average)
#
#  ****** Running generation 999 ******
#
# Population's average fitness: 238893.44889 stdev: 222652.65513
# Best fitness: 480400.00000 - size: (6, 15) - species 8 - id 23587
# Average adjusted fitness: 0.483
# Mean genetic distance 1.800, standard deviation 0.775
# Population of 29 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5  226     7  480400.0    0.375   225
#      7   18    10  480400.0    0.512    17
#      8   16    12  480400.0    0.562    14
# Total extinctions: 0
# Generation time: 21.560 sec (23.106 average)

# %%
with open('OUTPUT_2.txt') as f:
    text = f.read()

# %%
import re
import matplotlib.pyplot as plt

# Extract the fitness values from the text
fitness_values = []
for line in text.split('\n'):
    match = re.search(r'Best fitness: (\d+\.\d+)', line)
    if match:
        fitness_values.append(float(match.group(1)))

# Create a 2x2 grid of plots
plt.figure(figsize=(12, 10))

# Plot 1: Line plot of fitness values over generations
plt.subplot(2, 2, 1)
plt.plot(fitness_values)
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('Fitness Values Over Generations')

# Plot 2: Scatter plot of fitness values over generations
plt.subplot(2, 2, 2)
plt.scatter(range(len(fitness_values)), fitness_values)
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('Fitness Values Over Generations (Scatter Plot)')

# Plot 3: Box plot of fitness values over generations
plt.subplot(2, 2, 3)
plt.boxplot(fitness_values)
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('Fitness Values Over Generations (Box Plot)')

# Plot 4: Histogram of fitness values
plt.subplot(2, 2, 4)
plt.hist(fitness_values, bins=10)
plt.xlabel('Fitness')
plt.ylabel('Frequency')
plt.title('Distribution of Fitness Values')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
